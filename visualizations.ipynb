# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
log = pd.read_csv("log.txt", header = None, names = ["iteration", "train loss", "val loss", "hella swag", "train loss2", "val loss2", "hella swag2"])

# %%
log
# Out:
#        iteration                     train loss                     val loss  \
# 0              0   train_loss:10.99733829498291  val_loss:10.973273277282715
# 1              2  train_loss:10.864648818969727                val_loss:None
# 2              3   train_loss:10.72679615020752                val_loss:None
# 3              4  train_loss:10.584198951721191                val_loss:None
# 4              5  train_loss:10.439604759216309                val_loss:None
# ...          ...                            ...                          ...
# 17166      17235  train_loss:3.0812430381774902                val_loss:None
# 17167      17236  train_loss:3.0327835083007812                val_loss:None
# 17168      17237  train_loss:3.0560531616210938                val_loss:None
# 17169      17238   train_loss:3.022040843963623                val_loss:None
# 17170      17239    train_loss:3.10170578956604                val_loss:None
#
# ...

# %%
train_log = []
val_log = []
hls_log = []

iteration_counter = 0
for index, row in log.iterrows():
    train_log.append((float(row["train loss"].split(":")[1]), iteration_counter))
    if not(row["val loss"] == "val_loss:None"):
        val_log.append((float(row["val loss"].split(":")[1]), iteration_counter))
    if not(row["hella swag"] == "HellaSwag_acc:None"):
        hls_log.append((float(row["hella swag"].split(":")[1]), iteration_counter))
    iteration_counter +=1
    if not(pd.isnull(row["train loss2"])):
        train_log.append((float(row["train loss2"].split(":")[1]), iteration_counter))
        iteration_counter +=1

# %%
#See HLS final perfromance in other notebook...

# %%
train_x = [pair[1] for pair in train_log]
train_y = [pair[0] for pair in train_log]

val_x = [pair[1] for pair in val_log]
val_y = [pair[0] for pair in val_log]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot((train_x), (train_y), label='Training Loss', color='blue')
plt.plot((val_x), (val_y), label='Validation Loss', color='red')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss over Iterations')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot((train_x[1000:]), (train_y[1000:]), label='Training Loss', color='blue')
plt.plot((val_x[4:]), (val_y[4:]), label='Validation Loss', color='red')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Loss over Iterations')
plt.legend()
plt.grid(True)
plt.show()
